# %%
# Setup code for Google Colab
USE_COLAB = True
GOOGLE_DRIVE_PATH = ''
if USE_COLAB:
    print("Using Colab!")
    # %load_ext autoreload
    # %autoreload 2

    from google.colab import drive
    drive.mount('/content/drive')

    import os
    GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = 'EECS545/SVM-Variations'
    GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
    print(os.listdir(GOOGLE_DRIVE_PATH))

    import sys
    sys.path.append(GOOGLE_DRIVE_PATH)

    import torch
    import torch.nn as nn
    import torch.nn.functional as F
    import torchvision
    import statistics
    import random
    import time
    import math
    import numpy as np
    import cv2
    import copy
    import shutil
    import os
    import json

    import matplotlib.pyplot as plt
    # %matplotlib inline

    # !pip3 install -q idx2numpy

    # install qp solver
    # !pip3 install -q qpth
    # import qpth

    if torch.cuda.is_available:
      print('Good to go!')
    else:
      print('Please set GPU via Edit -> Notebook Settings.')
else:
    import torch
    import torch.nn as nn
    import torch.nn.functional as F
    import torchvision
    import statistics
    import random
    import time
    import math
    import numpy as np
    # import cv2
    import copy
    import shutil
    import os
    import json
    
    import matplotlib.pyplot as plt
    # %matplotlib inline

    # !pip3 install -q idx2numpy
# Out:
# Using Colab!
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['__pycache__', 'SVMGuide_loader.py', 'functions.py', 'Data', 'LinearSVM.py', 'Mnist_loader.py', 'KDD_loader.py', 'Kmeans.py', 'Evaluate_models.py', 'kernelSVM_try.ipynb', 'SVMClass.ipynb', 'KernelSVM.py', '25GB RAM', 'KmeanSVM_try.ipynb', 'KmeanSVM.py']
# Good to go!

# %% [markdown]
# ## Test on toy example

# %%
# Test k-mean SVM by toy example
import torch
import matplotlib.pyplot as plt
from functions import *
import scipy.io as sio
from KmeanSVM import *

# Colab with GPU
X, Y = load_data("toy_example", os.path.join(GOOGLE_DRIVE_PATH, "Data/toy_data.mat"), "gpu")
plot_data(X.cpu(), Y.cpu())
# Colab with CPU
# X, Y = load_data("toy_example", os.path.join(GOOGLE_DRIVE_PATH, "toy_data.mat")) # four clusters
# plot_data(X, Y)
# Run locally with CPU
# X, Y = load_data("toy_example") # four clusters
# plot_data(X, Y)

KmSVM = KmeanSVM(K=2)
KmSVM.train(X, Y)
KmSVM.plot_classifier([-3, 3, -3, 3])
# Out:
# X: torch.Size([400, 2]) , Y: torch.Size([400]) , on gpu
# X_test torch.Size([2500, 2]) self.centroid torch.Size([2, 2])

# %% [markdown]
# ## Test cross validation on SVMGuide1 dataset

# %%
from SVMGuide_loader import load_SVMGuide1
from KmeanSVM import *
x_train, y_train, x_test, y_test, mu, std = load_SVMGuide1(USE_COLAB, GOOGLE_DRIVE_PATH)
apply_KMSVM(x_train, y_train, x_test, y_test, cross=True)
# Max we get at: K = 4, lamb = 0.01, reg = 1e-05, and lr = 1 we get acc = 0.9662338495254517
# Out:
# at K = 2, lamb = 0.01, reg = 1e-09 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.01, reg = 1e-09 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 0.01, reg = 1e-09 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 0.01, reg = 1e-09 and lr = 50 we get acc = 0.9474025964736938
# at K = 2, lamb = 0.01, reg = 1e-09 and lr = 100 we get acc = 0.9561688303947449
# at K = 2, lamb = 0.01, reg = 1e-08 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.01, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 0.01, reg = 1e-08 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 0.01, reg = 1e-08 and lr = 50 we get acc = 0.9529220461845398
# at K = 2, lamb = 0.01, reg = 1e-08 and lr = 100 we get acc = 0.9571428298950195
# at K = 2, lamb = 0.01, reg = 1e-07 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.01, reg = 1e-07 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 0.01, reg = 1e-07 and lr = 10 we get acc = 0.962986946105957
# at K = 2, lamb = 0.01, reg = 1e-07 and lr = 50 we get acc = 0.9564935564994812
# at K = 2, lamb = 0.01, reg = 1e-07 and lr = 100 we get acc = 0.9506494402885437
# at K = 2, lamb = 0.01, reg = 1e-06 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.01, reg = 1e-06 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 0.01, reg = 1e-06 and lr = 10 we get acc = 0.9610388875007629
# at K = 2, lamb = 0.01, reg = 1e-06 and lr = 50 we get acc = 0.953896164894104
# at K = 2, lamb = 0.01, reg = 1e-06 and lr = 100 we get acc = 0.9457792043685913
# at K = 2, lamb = 0.01, reg = 1e-05 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.01, reg = 1e-05 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 0.01, reg = 1e-05 and lr = 10 we get acc = 0.9616883397102356
# at K = 2, lamb = 0.01, reg = 1e-05 and lr = 50 we get acc = 0.9529221653938293
# at K = 2, lamb = 0.01, reg = 1e-05 and lr = 100 we get acc = 0.949999988079071
# at K = 2, lamb = 0.1, reg = 1e-09 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.1, reg = 1e-09 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 0.1, reg = 1e-09 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 0.1, reg = 1e-09 and lr = 50 we get acc = 0.9474025964736938
# at K = 2, lamb = 0.1, reg = 1e-09 and lr = 100 we get acc = 0.9561688303947449
# at K = 2, lamb = 0.1, reg = 1e-08 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.1, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 0.1, reg = 1e-08 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 0.1, reg = 1e-08 and lr = 50 we get acc = 0.9529220461845398
# at K = 2, lamb = 0.1, reg = 1e-08 and lr = 100 we get acc = 0.9571428298950195
# at K = 2, lamb = 0.1, reg = 1e-07 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.1, reg = 1e-07 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 0.1, reg = 1e-07 and lr = 10 we get acc = 0.962986946105957
# at K = 2, lamb = 0.1, reg = 1e-07 and lr = 50 we get acc = 0.9564935564994812
# at K = 2, lamb = 0.1, reg = 1e-07 and lr = 100 we get acc = 0.9506494402885437
# at K = 2, lamb = 0.1, reg = 1e-06 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.1, reg = 1e-06 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 0.1, reg = 1e-06 and lr = 10 we get acc = 0.9610388875007629
# at K = 2, lamb = 0.1, reg = 1e-06 and lr = 50 we get acc = 0.953896164894104
# at K = 2, lamb = 0.1, reg = 1e-06 and lr = 100 we get acc = 0.9457792043685913
# at K = 2, lamb = 0.1, reg = 1e-05 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 0.1, reg = 1e-05 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 0.1, reg = 1e-05 and lr = 10 we get acc = 0.9616883397102356
# at K = 2, lamb = 0.1, reg = 1e-05 and lr = 50 we get acc = 0.9529221653938293
# at K = 2, lamb = 0.1, reg = 1e-05 and lr = 100 we get acc = 0.949999988079071
# at K = 2, lamb = 1, reg = 1e-09 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 1, reg = 1e-09 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 1, reg = 1e-09 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 1, reg = 1e-09 and lr = 50 we get acc = 0.9474025964736938
# at K = 2, lamb = 1, reg = 1e-09 and lr = 100 we get acc = 0.9561688303947449
# at K = 2, lamb = 1, reg = 1e-08 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 1, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 1, reg = 1e-08 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 1, reg = 1e-08 and lr = 50 we get acc = 0.9529220461845398
# at K = 2, lamb = 1, reg = 1e-08 and lr = 100 we get acc = 0.9571428298950195
# at K = 2, lamb = 1, reg = 1e-07 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 1, reg = 1e-07 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 1, reg = 1e-07 and lr = 10 we get acc = 0.962986946105957
# at K = 2, lamb = 1, reg = 1e-07 and lr = 50 we get acc = 0.9564935564994812
# at K = 2, lamb = 1, reg = 1e-07 and lr = 100 we get acc = 0.9506494402885437
# at K = 2, lamb = 1, reg = 1e-06 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 1, reg = 1e-06 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 1, reg = 1e-06 and lr = 10 we get acc = 0.9610388875007629
# at K = 2, lamb = 1, reg = 1e-06 and lr = 50 we get acc = 0.953896164894104
# at K = 2, lamb = 1, reg = 1e-06 and lr = 100 we get acc = 0.9457792043685913
# at K = 2, lamb = 1, reg = 1e-05 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 1, reg = 1e-05 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 1, reg = 1e-05 and lr = 10 we get acc = 0.9616883397102356
# at K = 2, lamb = 1, reg = 1e-05 and lr = 50 we get acc = 0.9529221653938293
# at K = 2, lamb = 1, reg = 1e-05 and lr = 100 we get acc = 0.949999988079071
# at K = 2, lamb = 10, reg = 1e-09 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 10, reg = 1e-09 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 10, reg = 1e-09 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 10, reg = 1e-09 and lr = 50 we get acc = 0.9474025964736938
# at K = 2, lamb = 10, reg = 1e-09 and lr = 100 we get acc = 0.9561688303947449
# at K = 2, lamb = 10, reg = 1e-08 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 10, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 10, reg = 1e-08 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 10, reg = 1e-08 and lr = 50 we get acc = 0.9529220461845398
# at K = 2, lamb = 10, reg = 1e-08 and lr = 100 we get acc = 0.9571428298950195
# at K = 2, lamb = 10, reg = 1e-07 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 10, reg = 1e-07 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 10, reg = 1e-07 and lr = 10 we get acc = 0.962986946105957
# at K = 2, lamb = 10, reg = 1e-07 and lr = 50 we get acc = 0.9564935564994812
# at K = 2, lamb = 10, reg = 1e-07 and lr = 100 we get acc = 0.9506494402885437
# at K = 2, lamb = 10, reg = 1e-06 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 10, reg = 1e-06 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 10, reg = 1e-06 and lr = 10 we get acc = 0.9610388875007629
# at K = 2, lamb = 10, reg = 1e-06 and lr = 50 we get acc = 0.953896164894104
# at K = 2, lamb = 10, reg = 1e-06 and lr = 100 we get acc = 0.9457792043685913
# at K = 2, lamb = 10, reg = 1e-05 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 10, reg = 1e-05 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 10, reg = 1e-05 and lr = 10 we get acc = 0.9616883397102356
# at K = 2, lamb = 10, reg = 1e-05 and lr = 50 we get acc = 0.9529221653938293
# at K = 2, lamb = 10, reg = 1e-05 and lr = 100 we get acc = 0.949999988079071
# at K = 2, lamb = 20, reg = 1e-09 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 20, reg = 1e-09 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 20, reg = 1e-09 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 20, reg = 1e-09 and lr = 50 we get acc = 0.9474025964736938
# at K = 2, lamb = 20, reg = 1e-09 and lr = 100 we get acc = 0.9561688303947449
# at K = 2, lamb = 20, reg = 1e-08 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 20, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 20, reg = 1e-08 and lr = 10 we get acc = 0.9607142210006714
# at K = 2, lamb = 20, reg = 1e-08 and lr = 50 we get acc = 0.9529220461845398
# at K = 2, lamb = 20, reg = 1e-08 and lr = 100 we get acc = 0.9571428298950195
# at K = 2, lamb = 20, reg = 1e-07 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 20, reg = 1e-07 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 20, reg = 1e-07 and lr = 10 we get acc = 0.962986946105957
# at K = 2, lamb = 20, reg = 1e-07 and lr = 50 we get acc = 0.9564935564994812
# at K = 2, lamb = 20, reg = 1e-07 and lr = 100 we get acc = 0.9506494402885437
# at K = 2, lamb = 20, reg = 1e-06 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 20, reg = 1e-06 and lr = 1 we get acc = 0.965584397315979
# at K = 2, lamb = 20, reg = 1e-06 and lr = 10 we get acc = 0.9610388875007629
# at K = 2, lamb = 20, reg = 1e-06 and lr = 50 we get acc = 0.953896164894104
# at K = 2, lamb = 20, reg = 1e-06 and lr = 100 we get acc = 0.9457792043685913
# at K = 2, lamb = 20, reg = 1e-05 and lr = 0.1 we get acc = 0.95941561460495
# at K = 2, lamb = 20, reg = 1e-05 and lr = 1 we get acc = 0.9652597308158875
# at K = 2, lamb = 20, reg = 1e-05 and lr = 10 we get acc = 0.9616883397102356
# at K = 2, lamb = 20, reg = 1e-05 and lr = 50 we get acc = 0.9529221653938293
# at K = 2, lamb = 20, reg = 1e-05 and lr = 100 we get acc = 0.949999988079071
# at K = 4, lamb = 0.01, reg = 1e-09 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.01, reg = 1e-09 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 0.01, reg = 1e-09 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 0.01, reg = 1e-09 and lr = 50 we get acc = 0.949999988079071
# at K = 4, lamb = 0.01, reg = 1e-09 and lr = 100 we get acc = 0.9503246545791626
# at K = 4, lamb = 0.01, reg = 1e-08 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.01, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 0.01, reg = 1e-08 and lr = 10 we get acc = 0.9574675559997559
# at K = 4, lamb = 0.01, reg = 1e-08 and lr = 50 we get acc = 0.9548701047897339
# at K = 4, lamb = 0.01, reg = 1e-08 and lr = 100 we get acc = 0.9545453786849976
# at K = 4, lamb = 0.01, reg = 1e-07 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.01, reg = 1e-07 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 0.01, reg = 1e-07 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 0.01, reg = 1e-07 and lr = 50 we get acc = 0.9487012624740601
# at K = 4, lamb = 0.01, reg = 1e-07 and lr = 100 we get acc = 0.9529220461845398
# at K = 4, lamb = 0.01, reg = 1e-06 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.01, reg = 1e-06 and lr = 1 we get acc = 0.9655844569206238
# at K = 4, lamb = 0.01, reg = 1e-06 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 0.01, reg = 1e-06 and lr = 50 we get acc = 0.9474025964736938
# at K = 4, lamb = 0.01, reg = 1e-06 and lr = 100 we get acc = 0.9555194973945618
# at K = 4, lamb = 0.01, reg = 1e-05 and lr = 0.1 we get acc = 0.9389610290527344
# at K = 4, lamb = 0.01, reg = 1e-05 and lr = 1 we get acc = 0.9662338495254517
# at K = 4, lamb = 0.01, reg = 1e-05 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 0.01, reg = 1e-05 and lr = 50 we get acc = 0.9529220461845398
# at K = 4, lamb = 0.01, reg = 1e-05 and lr = 100 we get acc = 0.9522727131843567
# at K = 4, lamb = 0.1, reg = 1e-09 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.1, reg = 1e-09 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 0.1, reg = 1e-09 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 0.1, reg = 1e-09 and lr = 50 we get acc = 0.949999988079071
# at K = 4, lamb = 0.1, reg = 1e-09 and lr = 100 we get acc = 0.9503246545791626
# at K = 4, lamb = 0.1, reg = 1e-08 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.1, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 0.1, reg = 1e-08 and lr = 10 we get acc = 0.9574675559997559
# at K = 4, lamb = 0.1, reg = 1e-08 and lr = 50 we get acc = 0.9548701047897339
# at K = 4, lamb = 0.1, reg = 1e-08 and lr = 100 we get acc = 0.9545453786849976
# at K = 4, lamb = 0.1, reg = 1e-07 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.1, reg = 1e-07 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 0.1, reg = 1e-07 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 0.1, reg = 1e-07 and lr = 50 we get acc = 0.9487012624740601
# at K = 4, lamb = 0.1, reg = 1e-07 and lr = 100 we get acc = 0.9529220461845398
# at K = 4, lamb = 0.1, reg = 1e-06 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 0.1, reg = 1e-06 and lr = 1 we get acc = 0.9655844569206238
# at K = 4, lamb = 0.1, reg = 1e-06 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 0.1, reg = 1e-06 and lr = 50 we get acc = 0.9474025964736938
# at K = 4, lamb = 0.1, reg = 1e-06 and lr = 100 we get acc = 0.9555194973945618
# at K = 4, lamb = 0.1, reg = 1e-05 and lr = 0.1 we get acc = 0.9389610290527344
# at K = 4, lamb = 0.1, reg = 1e-05 and lr = 1 we get acc = 0.9662338495254517
# at K = 4, lamb = 0.1, reg = 1e-05 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 0.1, reg = 1e-05 and lr = 50 we get acc = 0.9529220461845398
# at K = 4, lamb = 0.1, reg = 1e-05 and lr = 100 we get acc = 0.9522727131843567
# at K = 4, lamb = 1, reg = 1e-09 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 1, reg = 1e-09 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 1, reg = 1e-09 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 1, reg = 1e-09 and lr = 50 we get acc = 0.949999988079071
# at K = 4, lamb = 1, reg = 1e-09 and lr = 100 we get acc = 0.9503246545791626
# at K = 4, lamb = 1, reg = 1e-08 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 1, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 1, reg = 1e-08 and lr = 10 we get acc = 0.9574675559997559
# at K = 4, lamb = 1, reg = 1e-08 and lr = 50 we get acc = 0.9548701047897339
# at K = 4, lamb = 1, reg = 1e-08 and lr = 100 we get acc = 0.9545453786849976
# at K = 4, lamb = 1, reg = 1e-07 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 1, reg = 1e-07 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 1, reg = 1e-07 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 1, reg = 1e-07 and lr = 50 we get acc = 0.9487012624740601
# at K = 4, lamb = 1, reg = 1e-07 and lr = 100 we get acc = 0.9529220461845398
# at K = 4, lamb = 1, reg = 1e-06 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 1, reg = 1e-06 and lr = 1 we get acc = 0.9655844569206238
# at K = 4, lamb = 1, reg = 1e-06 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 1, reg = 1e-06 and lr = 50 we get acc = 0.9474025964736938
# at K = 4, lamb = 1, reg = 1e-06 and lr = 100 we get acc = 0.9555194973945618
# at K = 4, lamb = 1, reg = 1e-05 and lr = 0.1 we get acc = 0.9389610290527344
# at K = 4, lamb = 1, reg = 1e-05 and lr = 1 we get acc = 0.9662338495254517
# at K = 4, lamb = 1, reg = 1e-05 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 1, reg = 1e-05 and lr = 50 we get acc = 0.9529220461845398
# at K = 4, lamb = 1, reg = 1e-05 and lr = 100 we get acc = 0.9522727131843567
# at K = 4, lamb = 10, reg = 1e-09 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 10, reg = 1e-09 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 10, reg = 1e-09 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 10, reg = 1e-09 and lr = 50 we get acc = 0.949999988079071
# at K = 4, lamb = 10, reg = 1e-09 and lr = 100 we get acc = 0.9503246545791626
# at K = 4, lamb = 10, reg = 1e-08 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 10, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 10, reg = 1e-08 and lr = 10 we get acc = 0.9574675559997559
# at K = 4, lamb = 10, reg = 1e-08 and lr = 50 we get acc = 0.9548701047897339
# at K = 4, lamb = 10, reg = 1e-08 and lr = 100 we get acc = 0.9545453786849976
# at K = 4, lamb = 10, reg = 1e-07 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 10, reg = 1e-07 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 10, reg = 1e-07 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 10, reg = 1e-07 and lr = 50 we get acc = 0.9487012624740601
# at K = 4, lamb = 10, reg = 1e-07 and lr = 100 we get acc = 0.9529220461845398
# at K = 4, lamb = 10, reg = 1e-06 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 10, reg = 1e-06 and lr = 1 we get acc = 0.9655844569206238
# at K = 4, lamb = 10, reg = 1e-06 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 10, reg = 1e-06 and lr = 50 we get acc = 0.9474025964736938
# at K = 4, lamb = 10, reg = 1e-06 and lr = 100 we get acc = 0.9555194973945618
# at K = 4, lamb = 10, reg = 1e-05 and lr = 0.1 we get acc = 0.9389610290527344
# at K = 4, lamb = 10, reg = 1e-05 and lr = 1 we get acc = 0.9662338495254517
# at K = 4, lamb = 10, reg = 1e-05 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 10, reg = 1e-05 and lr = 50 we get acc = 0.9529220461845398
# at K = 4, lamb = 10, reg = 1e-05 and lr = 100 we get acc = 0.9522727131843567
# at K = 4, lamb = 20, reg = 1e-09 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 20, reg = 1e-09 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 20, reg = 1e-09 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 20, reg = 1e-09 and lr = 50 we get acc = 0.949999988079071
# at K = 4, lamb = 20, reg = 1e-09 and lr = 100 we get acc = 0.9503246545791626
# at K = 4, lamb = 20, reg = 1e-08 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 20, reg = 1e-08 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 20, reg = 1e-08 and lr = 10 we get acc = 0.9574675559997559
# at K = 4, lamb = 20, reg = 1e-08 and lr = 50 we get acc = 0.9548701047897339
# at K = 4, lamb = 20, reg = 1e-08 and lr = 100 we get acc = 0.9545453786849976
# at K = 4, lamb = 20, reg = 1e-07 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 20, reg = 1e-07 and lr = 1 we get acc = 0.9652597308158875
# at K = 4, lamb = 20, reg = 1e-07 and lr = 10 we get acc = 0.9568182229995728
# at K = 4, lamb = 20, reg = 1e-07 and lr = 50 we get acc = 0.9487012624740601
# at K = 4, lamb = 20, reg = 1e-07 and lr = 100 we get acc = 0.9529220461845398
# at K = 4, lamb = 20, reg = 1e-06 and lr = 0.1 we get acc = 0.938636302947998
# at K = 4, lamb = 20, reg = 1e-06 and lr = 1 we get acc = 0.9655844569206238
# at K = 4, lamb = 20, reg = 1e-06 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 20, reg = 1e-06 and lr = 50 we get acc = 0.9474025964736938
# at K = 4, lamb = 20, reg = 1e-06 and lr = 100 we get acc = 0.9555194973945618
# at K = 4, lamb = 20, reg = 1e-05 and lr = 0.1 we get acc = 0.9389610290527344
# at K = 4, lamb = 20, reg = 1e-05 and lr = 1 we get acc = 0.9662338495254517
# at K = 4, lamb = 20, reg = 1e-05 and lr = 10 we get acc = 0.9561688303947449
# at K = 4, lamb = 20, reg = 1e-05 and lr = 50 we get acc = 0.9529220461845398
# at K = 4, lamb = 20, reg = 1e-05 and lr = 100 we get acc = 0.9522727131843567
# at K = 8, lamb = 0.01, reg = 1e-09 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.01, reg = 1e-09 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.01, reg = 1e-09 and lr = 10 we get acc = 0.9555194973945618
# at K = 8, lamb = 0.01, reg = 1e-09 and lr = 50 we get acc = 0.9503247141838074
# at K = 8, lamb = 0.01, reg = 1e-09 and lr = 100 we get acc = 0.949999988079071
# at K = 8, lamb = 0.01, reg = 1e-08 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.01, reg = 1e-08 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.01, reg = 1e-08 and lr = 10 we get acc = 0.9558441042900085
# at K = 8, lamb = 0.01, reg = 1e-08 and lr = 50 we get acc = 0.9490259289741516
# at K = 8, lamb = 0.01, reg = 1e-08 and lr = 100 we get acc = 0.9503246545791626
# at K = 8, lamb = 0.01, reg = 1e-07 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.01, reg = 1e-07 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.01, reg = 1e-07 and lr = 10 we get acc = 0.9561689496040344
# at K = 8, lamb = 0.01, reg = 1e-07 and lr = 50 we get acc = 0.9457791447639465
# at K = 8, lamb = 0.01, reg = 1e-07 and lr = 100 we get acc = 0.9457792043685913
# at K = 8, lamb = 0.01, reg = 1e-06 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.01, reg = 1e-06 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.01, reg = 1e-06 and lr = 10 we get acc = 0.9551948308944702
# at K = 8, lamb = 0.01, reg = 1e-06 and lr = 50 we get acc = 0.9506493806838989
# at K = 8, lamb = 0.01, reg = 1e-06 and lr = 100 we get acc = 0.9487012624740601
# at K = 8, lamb = 0.01, reg = 1e-05 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.01, reg = 1e-05 and lr = 1 we get acc = 0.9571429491043091
# at K = 8, lamb = 0.01, reg = 1e-05 and lr = 10 we get acc = 0.9535714387893677
# at K = 8, lamb = 0.01, reg = 1e-05 and lr = 50 we get acc = 0.9477273225784302
# at K = 8, lamb = 0.01, reg = 1e-05 and lr = 100 we get acc = 0.9415584802627563
# at K = 8, lamb = 0.1, reg = 1e-09 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.1, reg = 1e-09 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.1, reg = 1e-09 and lr = 10 we get acc = 0.9555194973945618
# at K = 8, lamb = 0.1, reg = 1e-09 and lr = 50 we get acc = 0.9503247141838074
# at K = 8, lamb = 0.1, reg = 1e-09 and lr = 100 we get acc = 0.949999988079071
# at K = 8, lamb = 0.1, reg = 1e-08 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.1, reg = 1e-08 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.1, reg = 1e-08 and lr = 10 we get acc = 0.9558441042900085
# at K = 8, lamb = 0.1, reg = 1e-08 and lr = 50 we get acc = 0.9490259289741516
# at K = 8, lamb = 0.1, reg = 1e-08 and lr = 100 we get acc = 0.9503246545791626
# at K = 8, lamb = 0.1, reg = 1e-07 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.1, reg = 1e-07 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.1, reg = 1e-07 and lr = 10 we get acc = 0.9561689496040344
# at K = 8, lamb = 0.1, reg = 1e-07 and lr = 50 we get acc = 0.9457791447639465
# at K = 8, lamb = 0.1, reg = 1e-07 and lr = 100 we get acc = 0.9457792043685913
# at K = 8, lamb = 0.1, reg = 1e-06 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.1, reg = 1e-06 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 0.1, reg = 1e-06 and lr = 10 we get acc = 0.9551948308944702
# at K = 8, lamb = 0.1, reg = 1e-06 and lr = 50 we get acc = 0.9506493806838989
# at K = 8, lamb = 0.1, reg = 1e-06 and lr = 100 we get acc = 0.9487012624740601
# at K = 8, lamb = 0.1, reg = 1e-05 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 0.1, reg = 1e-05 and lr = 1 we get acc = 0.9571429491043091
# at K = 8, lamb = 0.1, reg = 1e-05 and lr = 10 we get acc = 0.9535714387893677
# at K = 8, lamb = 0.1, reg = 1e-05 and lr = 50 we get acc = 0.9477273225784302
# at K = 8, lamb = 0.1, reg = 1e-05 and lr = 100 we get acc = 0.9415584802627563
# at K = 8, lamb = 1, reg = 1e-09 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 1, reg = 1e-09 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 1, reg = 1e-09 and lr = 10 we get acc = 0.9555194973945618
# at K = 8, lamb = 1, reg = 1e-09 and lr = 50 we get acc = 0.9503247141838074
# at K = 8, lamb = 1, reg = 1e-09 and lr = 100 we get acc = 0.949999988079071
# at K = 8, lamb = 1, reg = 1e-08 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 1, reg = 1e-08 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 1, reg = 1e-08 and lr = 10 we get acc = 0.9558441042900085
# at K = 8, lamb = 1, reg = 1e-08 and lr = 50 we get acc = 0.9490259289741516
# at K = 8, lamb = 1, reg = 1e-08 and lr = 100 we get acc = 0.9503246545791626
# at K = 8, lamb = 1, reg = 1e-07 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 1, reg = 1e-07 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 1, reg = 1e-07 and lr = 10 we get acc = 0.9561689496040344
# at K = 8, lamb = 1, reg = 1e-07 and lr = 50 we get acc = 0.9457791447639465
# at K = 8, lamb = 1, reg = 1e-07 and lr = 100 we get acc = 0.9457792043685913
# at K = 8, lamb = 1, reg = 1e-06 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 1, reg = 1e-06 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 1, reg = 1e-06 and lr = 10 we get acc = 0.9551948308944702
# at K = 8, lamb = 1, reg = 1e-06 and lr = 50 we get acc = 0.9506493806838989
# at K = 8, lamb = 1, reg = 1e-06 and lr = 100 we get acc = 0.9487012624740601
# at K = 8, lamb = 1, reg = 1e-05 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 1, reg = 1e-05 and lr = 1 we get acc = 0.9571429491043091
# at K = 8, lamb = 1, reg = 1e-05 and lr = 10 we get acc = 0.9535714387893677
# at K = 8, lamb = 1, reg = 1e-05 and lr = 50 we get acc = 0.9477273225784302
# at K = 8, lamb = 1, reg = 1e-05 and lr = 100 we get acc = 0.9415584802627563
# at K = 8, lamb = 10, reg = 1e-09 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 10, reg = 1e-09 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 10, reg = 1e-09 and lr = 10 we get acc = 0.9555194973945618
# at K = 8, lamb = 10, reg = 1e-09 and lr = 50 we get acc = 0.9503247141838074
# at K = 8, lamb = 10, reg = 1e-09 and lr = 100 we get acc = 0.949999988079071
# at K = 8, lamb = 10, reg = 1e-08 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 10, reg = 1e-08 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 10, reg = 1e-08 and lr = 10 we get acc = 0.9558441042900085
# at K = 8, lamb = 10, reg = 1e-08 and lr = 50 we get acc = 0.9490259289741516
# at K = 8, lamb = 10, reg = 1e-08 and lr = 100 we get acc = 0.9503246545791626
# at K = 8, lamb = 10, reg = 1e-07 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 10, reg = 1e-07 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 10, reg = 1e-07 and lr = 10 we get acc = 0.9561689496040344
# at K = 8, lamb = 10, reg = 1e-07 and lr = 50 we get acc = 0.9457791447639465
# at K = 8, lamb = 10, reg = 1e-07 and lr = 100 we get acc = 0.9457792043685913
# at K = 8, lamb = 10, reg = 1e-06 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 10, reg = 1e-06 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 10, reg = 1e-06 and lr = 10 we get acc = 0.9551948308944702
# at K = 8, lamb = 10, reg = 1e-06 and lr = 50 we get acc = 0.9506493806838989
# at K = 8, lamb = 10, reg = 1e-06 and lr = 100 we get acc = 0.9487012624740601
# at K = 8, lamb = 10, reg = 1e-05 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 10, reg = 1e-05 and lr = 1 we get acc = 0.9571429491043091
# at K = 8, lamb = 10, reg = 1e-05 and lr = 10 we get acc = 0.9535714387893677
# at K = 8, lamb = 10, reg = 1e-05 and lr = 50 we get acc = 0.9477273225784302
# at K = 8, lamb = 10, reg = 1e-05 and lr = 100 we get acc = 0.9415584802627563
# at K = 8, lamb = 20, reg = 1e-09 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 20, reg = 1e-09 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 20, reg = 1e-09 and lr = 10 we get acc = 0.9555194973945618
# at K = 8, lamb = 20, reg = 1e-09 and lr = 50 we get acc = 0.9503247141838074
# at K = 8, lamb = 20, reg = 1e-09 and lr = 100 we get acc = 0.949999988079071
# at K = 8, lamb = 20, reg = 1e-08 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 20, reg = 1e-08 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 20, reg = 1e-08 and lr = 10 we get acc = 0.9558441042900085
# at K = 8, lamb = 20, reg = 1e-08 and lr = 50 we get acc = 0.9490259289741516
# at K = 8, lamb = 20, reg = 1e-08 and lr = 100 we get acc = 0.9503246545791626
# at K = 8, lamb = 20, reg = 1e-07 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 20, reg = 1e-07 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 20, reg = 1e-07 and lr = 10 we get acc = 0.9561689496040344
# at K = 8, lamb = 20, reg = 1e-07 and lr = 50 we get acc = 0.9457791447639465
# at K = 8, lamb = 20, reg = 1e-07 and lr = 100 we get acc = 0.9457792043685913
# at K = 8, lamb = 20, reg = 1e-06 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 20, reg = 1e-06 and lr = 1 we get acc = 0.9574675559997559
# at K = 8, lamb = 20, reg = 1e-06 and lr = 10 we get acc = 0.9551948308944702
# at K = 8, lamb = 20, reg = 1e-06 and lr = 50 we get acc = 0.9506493806838989
# at K = 8, lamb = 20, reg = 1e-06 and lr = 100 we get acc = 0.9487012624740601
# at K = 8, lamb = 20, reg = 1e-05 and lr = 0.1 we get acc = 0.9441558718681335
# at K = 8, lamb = 20, reg = 1e-05 and lr = 1 we get acc = 0.9571429491043091
# at K = 8, lamb = 20, reg = 1e-05 and lr = 10 we get acc = 0.9535714387893677
# at K = 8, lamb = 20, reg = 1e-05 and lr = 50 we get acc = 0.9477273225784302
# at K = 8, lamb = 20, reg = 1e-05 and lr = 100 we get acc = 0.9415584802627563
# at K = 10, lamb = 0.01, reg = 1e-09 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.01, reg = 1e-09 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.01, reg = 1e-09 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 0.01, reg = 1e-09 and lr = 50 we get acc = 0.952597439289093
# at K = 10, lamb = 0.01, reg = 1e-09 and lr = 100 we get acc = 0.9441558718681335
# at K = 10, lamb = 0.01, reg = 1e-08 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.01, reg = 1e-08 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.01, reg = 1e-08 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 0.01, reg = 1e-08 and lr = 50 we get acc = 0.9522727727890015
# at K = 10, lamb = 0.01, reg = 1e-08 and lr = 100 we get acc = 0.9448051452636719
# at K = 10, lamb = 0.01, reg = 1e-07 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.01, reg = 1e-07 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.01, reg = 1e-07 and lr = 10 we get acc = 0.9555194973945618
# at K = 10, lamb = 0.01, reg = 1e-07 and lr = 50 we get acc = 0.9490259885787964
# at K = 10, lamb = 0.01, reg = 1e-07 and lr = 100 we get acc = 0.951298713684082
# at K = 10, lamb = 0.01, reg = 1e-06 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.01, reg = 1e-06 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.01, reg = 1e-06 and lr = 10 we get acc = 0.9568181037902832
# at K = 10, lamb = 0.01, reg = 1e-06 and lr = 50 we get acc = 0.9516234397888184
# at K = 10, lamb = 0.01, reg = 1e-06 and lr = 100 we get acc = 0.9483766555786133
# at K = 10, lamb = 0.01, reg = 1e-05 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.01, reg = 1e-05 and lr = 1 we get acc = 0.9542207717895508
# at K = 10, lamb = 0.01, reg = 1e-05 and lr = 10 we get acc = 0.9548701047897339
# at K = 10, lamb = 0.01, reg = 1e-05 and lr = 50 we get acc = 0.9493505358695984
# at K = 10, lamb = 0.01, reg = 1e-05 and lr = 100 we get acc = 0.9461038708686829
# at K = 10, lamb = 0.1, reg = 1e-09 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.1, reg = 1e-09 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.1, reg = 1e-09 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 0.1, reg = 1e-09 and lr = 50 we get acc = 0.952597439289093
# at K = 10, lamb = 0.1, reg = 1e-09 and lr = 100 we get acc = 0.9441558718681335
# at K = 10, lamb = 0.1, reg = 1e-08 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.1, reg = 1e-08 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.1, reg = 1e-08 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 0.1, reg = 1e-08 and lr = 50 we get acc = 0.9522727727890015
# at K = 10, lamb = 0.1, reg = 1e-08 and lr = 100 we get acc = 0.9448051452636719
# at K = 10, lamb = 0.1, reg = 1e-07 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.1, reg = 1e-07 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.1, reg = 1e-07 and lr = 10 we get acc = 0.9555194973945618
# at K = 10, lamb = 0.1, reg = 1e-07 and lr = 50 we get acc = 0.9490259885787964
# at K = 10, lamb = 0.1, reg = 1e-07 and lr = 100 we get acc = 0.951298713684082
# at K = 10, lamb = 0.1, reg = 1e-06 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.1, reg = 1e-06 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 0.1, reg = 1e-06 and lr = 10 we get acc = 0.9568181037902832
# at K = 10, lamb = 0.1, reg = 1e-06 and lr = 50 we get acc = 0.9516234397888184
# at K = 10, lamb = 0.1, reg = 1e-06 and lr = 100 we get acc = 0.9483766555786133
# at K = 10, lamb = 0.1, reg = 1e-05 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 0.1, reg = 1e-05 and lr = 1 we get acc = 0.9542207717895508
# at K = 10, lamb = 0.1, reg = 1e-05 and lr = 10 we get acc = 0.9548701047897339
# at K = 10, lamb = 0.1, reg = 1e-05 and lr = 50 we get acc = 0.9493505358695984
# at K = 10, lamb = 0.1, reg = 1e-05 and lr = 100 we get acc = 0.9461038708686829
# at K = 10, lamb = 1, reg = 1e-09 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 1, reg = 1e-09 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 1, reg = 1e-09 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 1, reg = 1e-09 and lr = 50 we get acc = 0.952597439289093
# at K = 10, lamb = 1, reg = 1e-09 and lr = 100 we get acc = 0.9441558718681335
# at K = 10, lamb = 1, reg = 1e-08 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 1, reg = 1e-08 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 1, reg = 1e-08 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 1, reg = 1e-08 and lr = 50 we get acc = 0.9522727727890015
# at K = 10, lamb = 1, reg = 1e-08 and lr = 100 we get acc = 0.9448051452636719
# at K = 10, lamb = 1, reg = 1e-07 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 1, reg = 1e-07 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 1, reg = 1e-07 and lr = 10 we get acc = 0.9555194973945618
# at K = 10, lamb = 1, reg = 1e-07 and lr = 50 we get acc = 0.9490259885787964
# at K = 10, lamb = 1, reg = 1e-07 and lr = 100 we get acc = 0.951298713684082
# at K = 10, lamb = 1, reg = 1e-06 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 1, reg = 1e-06 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 1, reg = 1e-06 and lr = 10 we get acc = 0.9568181037902832
# at K = 10, lamb = 1, reg = 1e-06 and lr = 50 we get acc = 0.9516234397888184
# at K = 10, lamb = 1, reg = 1e-06 and lr = 100 we get acc = 0.9483766555786133
# at K = 10, lamb = 1, reg = 1e-05 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 1, reg = 1e-05 and lr = 1 we get acc = 0.9542207717895508
# at K = 10, lamb = 1, reg = 1e-05 and lr = 10 we get acc = 0.9548701047897339
# at K = 10, lamb = 1, reg = 1e-05 and lr = 50 we get acc = 0.9493505358695984
# at K = 10, lamb = 1, reg = 1e-05 and lr = 100 we get acc = 0.9461038708686829
# at K = 10, lamb = 10, reg = 1e-09 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 10, reg = 1e-09 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 10, reg = 1e-09 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 10, reg = 1e-09 and lr = 50 we get acc = 0.952597439289093
# at K = 10, lamb = 10, reg = 1e-09 and lr = 100 we get acc = 0.9441558718681335
# at K = 10, lamb = 10, reg = 1e-08 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 10, reg = 1e-08 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 10, reg = 1e-08 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 10, reg = 1e-08 and lr = 50 we get acc = 0.9522727727890015
# at K = 10, lamb = 10, reg = 1e-08 and lr = 100 we get acc = 0.9448051452636719
# at K = 10, lamb = 10, reg = 1e-07 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 10, reg = 1e-07 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 10, reg = 1e-07 and lr = 10 we get acc = 0.9555194973945618
# at K = 10, lamb = 10, reg = 1e-07 and lr = 50 we get acc = 0.9490259885787964
# at K = 10, lamb = 10, reg = 1e-07 and lr = 100 we get acc = 0.951298713684082
# at K = 10, lamb = 10, reg = 1e-06 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 10, reg = 1e-06 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 10, reg = 1e-06 and lr = 10 we get acc = 0.9568181037902832
# at K = 10, lamb = 10, reg = 1e-06 and lr = 50 we get acc = 0.9516234397888184
# at K = 10, lamb = 10, reg = 1e-06 and lr = 100 we get acc = 0.9483766555786133
# at K = 10, lamb = 10, reg = 1e-05 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 10, reg = 1e-05 and lr = 1 we get acc = 0.9542207717895508
# at K = 10, lamb = 10, reg = 1e-05 and lr = 10 we get acc = 0.9548701047897339
# at K = 10, lamb = 10, reg = 1e-05 and lr = 50 we get acc = 0.9493505358695984
# at K = 10, lamb = 10, reg = 1e-05 and lr = 100 we get acc = 0.9461038708686829
# at K = 10, lamb = 20, reg = 1e-09 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 20, reg = 1e-09 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 20, reg = 1e-09 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 20, reg = 1e-09 and lr = 50 we get acc = 0.952597439289093
# at K = 10, lamb = 20, reg = 1e-09 and lr = 100 we get acc = 0.9441558718681335
# at K = 10, lamb = 20, reg = 1e-08 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 20, reg = 1e-08 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 20, reg = 1e-08 and lr = 10 we get acc = 0.9561688303947449
# at K = 10, lamb = 20, reg = 1e-08 and lr = 50 we get acc = 0.9522727727890015
# at K = 10, lamb = 20, reg = 1e-08 and lr = 100 we get acc = 0.9448051452636719
# at K = 10, lamb = 20, reg = 1e-07 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 20, reg = 1e-07 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 20, reg = 1e-07 and lr = 10 we get acc = 0.9555194973945618
# at K = 10, lamb = 20, reg = 1e-07 and lr = 50 we get acc = 0.9490259885787964
# at K = 10, lamb = 20, reg = 1e-07 and lr = 100 we get acc = 0.951298713684082
# at K = 10, lamb = 20, reg = 1e-06 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 20, reg = 1e-06 and lr = 1 we get acc = 0.953896164894104
# at K = 10, lamb = 20, reg = 1e-06 and lr = 10 we get acc = 0.9568181037902832
# at K = 10, lamb = 20, reg = 1e-06 and lr = 50 we get acc = 0.9516234397888184
# at K = 10, lamb = 20, reg = 1e-06 and lr = 100 we get acc = 0.9483766555786133
# at K = 10, lamb = 20, reg = 1e-05 and lr = 0.1 we get acc = 0.9444805979728699
# at K = 10, lamb = 20, reg = 1e-05 and lr = 1 we get acc = 0.9542207717895508
# at K = 10, lamb = 20, reg = 1e-05 and lr = 10 we get acc = 0.9548701047897339
# at K = 10, lamb = 20, reg = 1e-05 and lr = 50 we get acc = 0.9493505358695984
# at K = 10, lamb = 20, reg = 1e-05 and lr = 100 we get acc = 0.9461038708686829
# Max we get at: K = 4, lamb = 0.01, reg = 1e-05, and lr = 1 we get acc = 0.9662338495254517
# tensor(0.9595, device='cuda:0')
# (tensor([0.7562, 0.4774, 0.5429, 0.5277, 0.3373, 0.3969, 0.3245, 0.4064, 0.3901,
#          0.3827, 0.3801, 0.3735, 0.2796, 0.3716, 0.4997, 0.3781, 0.3113, 0.3413,
#          0.2089, 0.3115, 0.3344, 0.2510, 0.3229, 0.2584, 0.2443, 0.2648, 0.2657,
#          0.1871, 0.3240, 0.2415, 0.2479, 0.2960, 0.2581, 0.2274, 0.2768, 0.2849,
#          0.2013, 0.2384, 0.2431, 0.2335, 0.2421, 0.2645, 0.1801, 0.2059, 0.1734,
#          0.2036, 0.2550, 0.2360, 0.2272, 0.2126, 0.1626, 0.1353, 0.2577, 0.2572,
#          0.2549, 0.2408, 0.2158, 0.2442, 0.2115, 0.1914, 0.2131, 0.2071, 0.1943,
#          0.1863, 0.1821, 0.2183, 0.2338, 0.1756, 0.2158, 0.1650, 0.2128, 0.2549,
#          0.2261, 0.1528, 0.1719, 0.2192, 0.1345, 0.2270, 0.1554, 0.1864, 0.1719,
#          0.2748, 0.1857, 0.1528, 0.1864, 0.1537, 0.1779, 0.0940, 0.1413, 0.1076,
#          0.1829, 0.1956, 0.1999, 0.2184, 0.1299, 0.1230, 0.2004, 0.1531, 0.1009,
#          0.1866, 0.1381, 0.1980, 0.2114, 0.1008, 0.1898, 0.1268, 0.1811, 0.2399,
#          0.0993, 0.1146, 0.2027, 0.1389, 0.1456, 0.1698, 0.1954, 0.1961, 0.1822,
#          0.1721, 0.1813, 0.1589, 0.1929, 0.1073, 0.1300, 0.1389, 0.1588, 0.1818,
#          0.1632, 0.1110, 0.1706, 0.1322, 0.1497, 0.1100, 0.1162, 0.1436, 0.1648,
#          0.1616, 0.1242, 0.0852, 0.2041, 0.1362, 0.1600, 0.1491, 0.1965, 0.0904,
#          0.1218, 0.2056, 0.1775, 0.1205, 0.1798, 0.1216, 0.2197, 0.1541, 0.1836,
#          0.1512, 0.1047, 0.1566, 0.1487, 0.1154, 0.2071, 0.1547, 0.1600, 0.1384,
#          0.1548, 0.1423, 0.1175, 0.1871, 0.1101, 0.1226, 0.1144, 0.1435, 0.1723,
#          0.1551, 0.1617, 0.2140, 0.1052, 0.1584, 0.1175, 0.1390, 0.1597, 0.1365,
#          0.0808, 0.1226, 0.1802, 0.1694, 0.1786, 0.1195, 0.1760, 0.0920, 0.1035,
#          0.1009, 0.1222, 0.1200, 0.1640, 0.1561, 0.0894, 0.1604, 0.1709, 0.1385,
#          0.1320, 0.1383, 0.1855, 0.1078, 0.1776, 0.1189, 0.1129, 0.0973, 0.1358,
#          0.1574, 0.1420, 0.1596, 0.1542, 0.0987, 0.1382, 0.1557, 0.1320, 0.1238,
#          0.1458, 0.1417, 0.1354, 0.1554, 0.1257, 0.2047, 0.0946, 0.1119, 0.1409,
#          0.1204, 0.1182, 0.1324, 0.1130, 0.1396, 0.1157, 0.1817, 0.1164, 0.1368,
#          0.1341, 0.0996, 0.1430, 0.1714, 0.1560, 0.1098, 0.1779, 0.2047, 0.1156,
#          0.1493, 0.1175, 0.1268, 0.0960, 0.1255, 0.1121, 0.1852, 0.1768, 0.0986,
#          0.1159, 0.1174, 0.1208, 0.1158, 0.1069, 0.0863, 0.1576, 0.0766, 0.1383,
#          0.1134, 0.0852, 0.1145, 0.1486, 0.1396, 0.1286, 0.1567, 0.1346, 0.1385,
#          0.1336, 0.1713, 0.1344, 0.1262, 0.0857, 0.1343, 0.1123, 0.1165, 0.1040,
#          0.0750, 0.1056, 0.1201, 0.1527, 0.0847, 0.1375, 0.1697, 0.1464, 0.1036,
#          0.1041, 0.1359, 0.1796, 0.1128, 0.0854, 0.1192, 0.1433, 0.1387, 0.0978,
#          0.0909, 0.1584, 0.1464, 0.1260, 0.1560, 0.1769, 0.1562, 0.1606, 0.1293,
#          0.1689, 0.1018, 0.1156, 0.1576, 0.1342, 0.0921, 0.1725, 0.1430, 0.1128,
#          0.1149, 0.1356, 0.1384, 0.0935, 0.1740, 0.0910, 0.0509, 0.1332, 0.1409,
#          0.1423, 0.0925, 0.0759, 0.1008, 0.0893, 0.0967, 0.1117, 0.1078, 0.0930,
#          0.1419, 0.0866, 0.1153, 0.1197, 0.1418, 0.1608, 0.1619, 0.1223, 0.1490,
#          0.0996, 0.1264, 0.1061, 0.1148, 0.1379, 0.1217, 0.1459, 0.1346, 0.0880,
#          0.1151, 0.1025, 0.1239, 0.1005, 0.1606, 0.1048, 0.1474, 0.0899, 0.1138,
#          0.0701, 0.1364, 0.1193, 0.1434, 0.1039, 0.1458, 0.0699, 0.1282, 0.0959,
#          0.1682, 0.1747, 0.1102, 0.0971, 0.1182, 0.1366, 0.1483, 0.1030, 0.1251,
#          0.1175, 0.0991, 0.1049, 0.1122, 0.0857, 0.1172, 0.1257, 0.0928, 0.1153,
#          0.0586, 0.0994, 0.1691, 0.1073, 0.1155, 0.0817, 0.0832, 0.1141, 0.0637,
#          0.1039, 0.1357, 0.0963, 0.0788, 0.0726, 0.1235, 0.1535, 0.0991, 0.0879,
#          0.1629, 0.1436, 0.1515, 0.1151, 0.0995, 0.0977, 0.1152, 0.0748, 0.1039,
#          0.0848, 0.0879, 0.0921, 0.0993, 0.0543, 0.1036, 0.1178, 0.1381, 0.0969,
#          0.0969, 0.0822, 0.1014, 0.0940, 0.1468, 0.0805, 0.0870, 0.0881, 0.1016,
#          0.1002, 0.1250, 0.0947, 0.0952, 0.1307, 0.1333, 0.1199, 0.0922, 0.1161,
#          0.1662, 0.1034, 0.1373, 0.1325, 0.0704, 0.0928, 0.0889, 0.0981, 0.0874,
#          0.1364, 0.1530, 0.1210, 0.0827, 0.1271, 0.1416, 0.1044, 0.0787, 0.1226,
#          0.0953, 0.1353, 0.1013, 0.1004, 0.1352, 0.1613, 0.0751, 0.1169, 0.1293,
#          0.1091, 0.1612, 0.0930, 0.1815, 0.1038, 0.0743, 0.1104, 0.1076, 0.1351,
#          0.1154, 0.0878, 0.0646, 0.1064, 0.1321, 0.0904, 0.0999, 0.0946, 0.0842,
#          0.0771, 0.1335, 0.1059, 0.0817, 0.0819, 0.1086, 0.1445, 0.1577, 0.0704,
#          0.0931, 0.1114, 0.1035, 0.1365, 0.1211, 0.2141, 0.1018, 0.1026, 0.0963,
#          0.1217, 0.1963, 0.1778, 0.0892, 0.0843, 0.1004, 0.1210, 0.1088, 0.0982,
#          0.1091, 0.1074, 0.1081, 0.1024, 0.0973, 0.1114, 0.1438, 0.0981, 0.1584,
#          0.1084, 0.1261, 0.1494, 0.1071, 0.1025, 0.0722, 0.1029, 0.0950, 0.1217,
#          0.1395, 0.1169, 0.1316, 0.1088, 0.0902, 0.0961, 0.0883, 0.1187, 0.0938,
#          0.1323, 0.0660, 0.1204, 0.1230, 0.1136, 0.1031, 0.1150, 0.1006, 0.0967,
#          0.0589, 0.0938, 0.0975, 0.0838, 0.0729, 0.0789, 0.1116, 0.1350, 0.1133,
#          0.1523, 0.1358, 0.1250, 0.0757, 0.1222, 0.1526, 0.1137, 0.0782, 0.0607,
#          0.1389, 0.1069, 0.1360, 0.1121, 0.1318, 0.1121, 0.0595, 0.0892, 0.0609,
#          0.0920, 0.1041, 0.1146, 0.0690, 0.1085, 0.1102, 0.1163, 0.1586, 0.0992,
#          0.1320, 0.0791, 0.1271, 0.0954, 0.1088, 0.0972, 0.0946, 0.0837, 0.1182,
#          0.0980, 0.0891, 0.0883, 0.1308, 0.1235, 0.0824, 0.0978, 0.1067, 0.0687,
#          0.1372, 0.1336, 0.1052, 0.1374, 0.0569, 0.0760, 0.1013, 0.0824, 0.1429,
#          0.1214, 0.0748, 0.1150, 0.1295, 0.0959, 0.1147, 0.0745, 0.1200, 0.1105,
#          0.1087, 0.0862, 0.1025, 0.0966, 0.1631, 0.0798, 0.0433, 0.0806, 0.1751,
#          0.1284, 0.1129, 0.1013, 0.1148, 0.1059, 0.0630, 0.0831, 0.0931, 0.0764,
#          0.1031, 0.0988, 0.0866, 0.1046, 0.1090, 0.0912, 0.0990, 0.1553, 0.0861,
#          0.0663, 0.1257, 0.1052, 0.0841, 0.1594, 0.0970, 0.1202, 0.0811, 0.0737,
#          0.0958, 0.1114, 0.1416, 0.0701, 0.1349, 0.1136, 0.1141, 0.0615, 0.0819,
#          0.1062, 0.0883, 0.1030, 0.1018, 0.0950, 0.0723, 0.1192, 0.1047, 0.0770,
#          0.1002, 0.0873, 0.0804, 0.1224, 0.0532, 0.0768, 0.0811, 0.0728, 0.0802,
#          0.1466, 0.1342, 0.0754, 0.1081, 0.1522, 0.1175, 0.1640, 0.0856, 0.0457,
#          0.0945, 0.0884, 0.0826, 0.0965, 0.1310, 0.1314, 0.1403, 0.0959, 0.1157,
#          0.1177, 0.0894, 0.1391, 0.1063, 0.0875, 0.1207, 0.1056, 0.1431, 0.1265,
#          0.1107, 0.1185, 0.0756, 0.0619, 0.0661, 0.0974, 0.1014, 0.1044, 0.0809,
#          0.0979, 0.1141, 0.1329, 0.1268, 0.1055, 0.0942, 0.1048, 0.0790, 0.1083,
#          0.1082, 0.1402, 0.1133, 0.0783, 0.0936, 0.1486, 0.0878, 0.0762, 0.1283,
#          0.0619, 0.1052, 0.1256, 0.0933, 0.0735, 0.0445, 0.0681, 0.1451, 0.1001,
#          0.0985, 0.0941, 0.1486, 0.1055, 0.0800, 0.1539, 0.0687, 0.1280, 0.0993,
#          0.0818, 0.1192, 0.1427, 0.0922, 0.0925, 0.0800, 0.0959, 0.0749, 0.0647,
#          0.0903, 0.1019, 0.1077, 0.0943, 0.0921, 0.1676, 0.0966, 0.0754, 0.0991,
#          0.1076, 0.0707, 0.0706, 0.0967, 0.0864, 0.0655, 0.1406, 0.1348, 0.1294,
#          0.0962, 0.0860, 0.0885, 0.1111, 0.1665, 0.1163, 0.1158, 0.0755, 0.0950,
#          0.1380, 0.1084, 0.0963, 0.1369, 0.1313, 0.1224, 0.1483, 0.0806, 0.1384,
#          0.1194, 0.1415, 0.1497, 0.1295, 0.0903, 0.1634, 0.0885, 0.1493, 0.1163,
#          0.0674, 0.0549, 0.0806, 0.1469, 0.1062, 0.1126, 0.1554, 0.0745, 0.0894,
#          0.1328, 0.1450, 0.1382, 0.1138, 0.0868, 0.1017, 0.0799, 0.0821, 0.1096,
#          0.0985, 0.0985, 0.1235, 0.0705, 0.1297, 0.1684, 0.0684, 0.0569, 0.1459,
#          0.0999, 0.1106, 0.1093, 0.1323, 0.1340, 0.1112, 0.0936, 0.0893, 0.1468,
#          0.0991, 0.1038, 0.0694, 0.0698, 0.0644, 0.1610, 0.1414, 0.1333, 0.1614,
#          0.0796, 0.1084, 0.1057, 0.0950, 0.0929, 0.1012, 0.1466, 0.1421, 0.0847,
#          0.1527, 0.1307, 0.1270, 0.1079, 0.1159, 0.1245, 0.0751, 0.1399, 0.1407,
#          0.1641, 0.0997, 0.0934, 0.0886, 0.1036, 0.1586, 0.1016, 0.0931, 0.0734,
#          0.1144, 0.0834, 0.1288, 0.0839, 0.0626, 0.0748, 0.0757, 0.0816, 0.0735,
#          0.0748, 0.0939, 0.1107, 0.1479, 0.1558, 0.1083, 0.1366, 0.0821, 0.1208,
#          0.1294, 0.1231, 0.0913, 0.1296, 0.0934, 0.0663, 0.0744, 0.1127, 0.0640,
#          0.1180, 0.0911, 0.0966, 0.0611, 0.0917, 0.1358, 0.1043, 0.1245, 0.1092,
#          0.1066, 0.1367, 0.0687, 0.0686, 0.1037, 0.0857, 0.1310, 0.0984, 0.1330,
#          0.0799, 0.1137, 0.1072, 0.0857, 0.0927, 0.1148, 0.0865, 0.1211, 0.0821,
#          0.1303, 0.0790, 0.1217, 0.0793, 0.1721, 0.1026, 0.1052, 0.0985, 0.0695,
#          0.1648, 0.0934, 0.0924, 0.0947, 0.0977, 0.0576, 0.0754, 0.1357, 0.0808,
#          0.1642, 0.1021, 0.1442, 0.1424, 0.1114, 0.0721, 0.1248, 0.0946, 0.0806,
#          0.0943, 0.0780, 0.0855, 0.1298, 0.0679, 0.1332, 0.1883, 0.1130, 0.1434,
#          0.0584, 0.1142, 0.1629, 0.0947, 0.0974, 0.1068, 0.0908, 0.0792, 0.1607,
#          0.0441, 0.1232, 0.0871, 0.0460, 0.0968, 0.1475, 0.1527, 0.1152, 0.0964,
#          0.0762, 0.0963, 0.1604, 0.1205, 0.1069, 0.0745, 0.0714, 0.1020, 0.1297,
#          0.1048], device='cuda:0', grad_fn=<CopySlices>),
#  <KmeanSVM.KmeanSVM at 0x7f09864a7518>)

# %% [markdown]
# ## Evaluate on Mnist, SVMGuide1, and KDD dataset

# %%
from Evaluate_models import *
from KmeanSVM import *

KMSVM = KmeanSVM()
KMSVM_time_oe, KMSVM_acc_oe, KMSVM_time_38, KMSVM_acc_38 = evaluate_using_mnist(KMSVM, USE_COLAB, GOOGLE_DRIVE_PATH)
KMSVM_time_svmg, KMSVM_acc_svmg = evaluate_using_SVM_Guide1(KMSVM, USE_COLAB, GOOGLE_DRIVE_PATH)
KMSVM_time_kdd, KMSVM_acc_kdd = evaluate_using_KDD(KMSVM, USE_COLAB, GOOGLE_DRIVE_PATH)

# KMSVM_time_oe, KMSVM_acc_oe, KMSVM_time_38, KMSVM_acc_38 = evaluate_using_mnist(KMSVM)
# KMSVM_time_svmg, KMSVM_acc_svmg = evaluate_using_SVM_Guide1(KMSVM)
# KMSVM_time_kdd, KMSVM_acc_kdd = evaluate_using_KDD(KMSVM)

print("Using KMSVM: Time = ", KMSVM_time_oe, "  acc = ", KMSVM_acc_oe)
print("Using KMSVM: Time = ", KMSVM_time_38, "  acc = ", KMSVM_acc_38)
print("Using KMSVM: Time = ", KMSVM_time_svmg, "  acc = ", KMSVM_acc_svmg)
print("Using KMSVM: Time = ", KMSVM_time_kdd, "  acc = ", KMSVM_acc_kdd)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-7-4f54e7cdc90c> in <module>
#       7 # KMSVM_time_kdd, KMSVM_acc_kdd = evaluate_using_KDD(KMSVM, USE_COLAB, GOOGLE_DRIVE_PATH)
#       8
# ----> 9 KMSVM_time_oe, KMSVM_acc_oe, KMSVM_time_38, KMSVM_acc_38 = evaluate_using_mnist(KMSVM)
#      10 KMSVM_time_svmg, KMSVM_acc_svmg = evaluate_using_SVM_Guide1(KMSVM)
#      11 KMSVM_time_kdd, KMSVM_acc_kdd = evaluate_using_KDD(KMSVM)
#
# D:\UM\EECS_545\Final_Project\SVM-Variations\Evaluate_models.py in evaluate_using_mnist(model, use_colab, path)
#      15     # load odd/even data first
#      16     import Mnist_loader as mnist
# ---> 17     x_train, y_train, x_test, y_test = mnist.load_odd_even_Mnist(USE_COLAB=use_colab, path=path)
#      18     x_train, x_test, mu, std = mnist.preprocess_Mnist(x_train, x_test)
#      19
#
# D:\UM\EECS_545\Final_Project\SVM-Variations\Mnist_loader.py in load_odd_even_Mnist(num_train, num_test, USE_COLAB, path)
#     167     """
#     168     # load a random sample from Mnist dataset
# --> 169     train_x, train_y, test_x, test_y = load_sample_Mnist(num_train, num_test, USE_COLAB, path)
#     170
#     171     # convert the odd labels to -1
#
# D:\UM\EECS_545\Final_Project\SVM-Variations\Mnist_loader.py in load_sample_Mnist(num_train, num_test, USE_COLAB, path)
#     116
#     117     # get the full Mnist dataset
# --> 118     train_x_full, train_y_full, test_x_full, test_y_full = load_full_Mnist(USE_COLAB, path)
#     119
#     120     temp_train_random_indices = np.random.permutation(train_x_full.shape[0]) # get random indices for all train set
#
# D:\UM\EECS_545\Final_Project\SVM-Variations\Mnist_loader.py in load_full_Mnist(USE_COLAB, path)
#      83
#      84
# ---> 85     train_x_full = torch.tensor(np.array(idx2numpy.convert_from_file(train_images_file))).to(dtype = torch.float32, device = 'cuda')
#      86     train_y_full = torch.tensor(np.array(idx2numpy.convert_from_file(train_labels_file))).to(dtype = torch.int32, device = 'cuda')
#      87     test_x_full = torch.tensor(np.array(idx2numpy.convert_from_file(test_images_file))).to(dtype = torch.float32, device = 'cuda')
#
# ~\anaconda3\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     184             raise RuntimeError(
#     185                 "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 186         _check_driver()
#     187         if _cudart is None:
#     188             raise AssertionError(
#
# ~\anaconda3\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      63         if torch._C._cuda_getDriverVersion() == 0:
#      64             # found no NVIDIA driver on the system
# ---> 65             raise AssertionError("""
#      66 Found no NVIDIA driver on your system. Please check that you
#      67 have an NVIDIA GPU and installed a driver from
#
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# have an NVIDIA GPU and installed a driver from
# http://www.nvidia.com/Download/index.aspx
